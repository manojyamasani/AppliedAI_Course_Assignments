# %% [markdown]
# ## Deep Learning:

# %% [markdown]
# <pre>
# 1. ImageDataGenerator
# 2. Pipeline using tf.data
# </pre>

# %% [markdown]
# <pre>
# As discussed in Previous notebooks, to train NN efficiently with less train time, we have to write better data pipelines.
# For Images, Keras is giving ImageDataGenerator to get images to RAM/GPU in batches.
# But you can write your own pipelines with tf.data API.
# </pre>

# %% [markdown]
# Download the data from <a href='https://www.kaggle.com/prasunroy/natural-images'>here</a>

# %% [markdown]
# <pre>
# <b>ImageDataGenerator</b>
# </pre>

# %%
 # %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow as tf
import os
import numpy as np
import pandas as pd

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
dir_path = "/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning"

# %%
# !unzip "/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural-images.zip" -d "/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0204.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0205.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0206.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0207.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0208.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0209.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0210.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0211.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0212.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0213.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0214.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0215.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0216.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0217.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0218.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0219.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0220.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0221.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0222.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0223.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0224.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0225.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0226.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0227.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0228.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0229.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0230.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0231.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0232.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0233.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0234.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0235.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0236.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0237.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0238.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0239.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0240.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0241.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0242.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0243.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0244.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0245.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0246.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0247.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0248.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0249.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0250.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0251.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0252.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0253.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0254.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0255.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0256.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0257.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0258.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0259.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0260.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0261.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0262.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0263.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0264.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0265.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0266.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0267.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0268.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0269.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0270.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0271.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0272.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0273.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0274.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0275.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0276.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0277.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0278.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0279.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0280.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0281.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0282.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0283.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0284.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0285.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0286.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0287.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0288.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0289.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0290.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0291.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0292.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0293.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0294.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0295.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0296.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0297.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0298.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0299.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0300.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0301.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0302.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0303.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0304.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0305.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0306.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0307.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0308.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0309.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0310.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0311.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0312.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0313.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0314.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0315.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0316.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0317.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0318.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0319.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0320.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0321.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0322.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0323.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0324.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0325.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0326.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0327.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0328.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0329.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0330.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0331.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0332.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0333.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0334.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0335.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0336.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0337.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0338.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0339.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0340.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0341.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0342.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0343.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0344.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0345.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0346.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0347.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0348.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0349.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0350.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0351.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0352.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0353.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0354.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0355.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0356.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0357.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0358.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0359.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0360.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0361.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0362.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0363.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0364.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0365.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0366.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0367.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0368.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0369.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0370.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0371.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0372.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0373.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0374.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0375.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0376.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0377.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0378.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0379.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0380.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0381.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0382.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0383.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0384.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0385.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0386.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0387.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0388.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0389.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0390.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0391.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0392.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0393.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0394.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0395.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0396.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0397.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0398.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0399.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0400.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0401.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0402.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0403.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0404.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0405.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0406.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0407.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0408.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0409.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0410.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0411.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0412.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0413.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0414.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0415.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0416.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0417.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0418.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0419.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0420.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0421.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0422.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0423.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0424.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0425.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0426.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0427.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0428.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0429.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0430.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0431.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0432.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0433.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0434.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0435.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0436.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0437.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0438.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0439.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0440.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0441.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0442.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0443.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0444.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0445.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0446.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0447.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0448.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0449.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0450.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0451.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0452.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0453.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0454.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0455.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0456.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0457.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0458.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0459.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0460.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0461.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0462.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0463.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0464.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0465.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0466.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0467.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0468.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0469.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0470.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0471.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0472.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0473.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0474.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0475.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0476.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0477.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0478.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0479.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0480.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0481.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0482.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0483.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0484.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0485.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0486.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0487.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0488.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0489.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0490.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0491.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0492.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0493.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0494.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0495.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0496.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0497.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0498.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0499.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0500.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0501.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0502.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0503.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0504.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0505.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0506.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0507.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0508.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0509.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0510.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0511.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0512.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0513.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0514.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0515.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0516.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0517.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0518.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0519.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0520.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0521.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0522.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0523.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0524.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0525.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0526.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0527.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0528.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0529.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0530.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0531.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0532.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0533.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0534.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0535.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0536.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0537.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0538.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0539.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0540.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0541.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0542.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0543.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0544.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0545.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0546.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0547.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0548.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0549.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0550.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0551.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0552.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0553.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0554.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0555.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0556.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0557.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0558.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0559.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0560.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0561.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0562.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0563.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0564.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0565.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0566.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0567.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0568.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0569.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0570.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0571.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0572.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0573.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0574.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0575.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0576.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0577.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0578.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0579.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0580.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0581.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0582.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0583.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0584.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0585.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0586.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0587.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0588.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0589.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0590.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0591.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0592.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0593.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0594.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0595.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0596.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0597.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0598.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0599.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0600.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0601.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0602.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0603.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0604.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0605.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0606.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0607.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0608.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0609.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0610.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0611.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0612.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0613.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0614.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0615.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0616.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0617.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0618.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0619.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0620.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0621.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0622.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0623.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0624.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0625.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0626.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0627.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0628.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0629.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0630.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0631.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0632.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0633.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0634.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0635.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0636.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0637.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0638.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0639.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0640.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0641.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0642.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0643.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0644.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0645.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0646.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0647.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0648.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0649.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0650.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0651.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0652.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0653.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0654.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0655.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0656.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0657.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0658.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat/cat_0659.jpg
# ...
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0842.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0843.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0844.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0845.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0846.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0847.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0848.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0849.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0850.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0851.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0852.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0853.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0854.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0855.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0856.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0857.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0858.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0859.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0860.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0861.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0862.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0863.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0864.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0865.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0866.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0867.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0868.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0869.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0870.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0871.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0872.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0873.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0874.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0875.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0876.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0877.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0878.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0879.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0880.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0881.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0882.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0883.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0884.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0885.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0886.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0887.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0888.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0889.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0890.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0891.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0892.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0893.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0894.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0895.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0896.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0897.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0898.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0899.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0900.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0901.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0902.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0903.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0904.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0905.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0906.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0907.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0908.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0909.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0910.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0911.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0912.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0913.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0914.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0915.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0916.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0917.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0918.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0919.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0920.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0921.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0922.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0923.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0924.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0925.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0926.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0927.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0928.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0929.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0930.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0931.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0932.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0933.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0934.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0935.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0936.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0937.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0938.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0939.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0940.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0941.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0942.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0943.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0944.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0945.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0946.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0947.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0948.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0949.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0950.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0951.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0952.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0953.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0954.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0955.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0956.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0957.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0958.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0959.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0960.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0961.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0962.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0963.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0964.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0965.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0966.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0967.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0968.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0969.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0970.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0971.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0972.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0973.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0974.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0975.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0976.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0977.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0978.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0979.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0980.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0981.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0982.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0983.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0984.jpg
#   inflating: /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person/person_0985.jpg

# %%
dir_path = dir_path+"/natural_images"
os.listdir(dir_path)
# Out:
# ['airplane', 'car', 'cat', 'dog', 'flower', 'fruit', 'motorbike', 'person']

# %%
for i in os.listdir(dir_path):
    print("No of Images in ",i," category is ",len(os.listdir(os.path.join(dir_path,i))))
# Out:
# No of Images in  airplane  category is  727
# No of Images in  car  category is  968
# No of Images in  cat  category is  885
# No of Images in  dog  category is  702
# No of Images in  flower  category is  843
# No of Images in  fruit  category is  1000
# No of Images in  motorbike  category is  788
# No of Images in  person  category is  986

# %%
#import openCV
import cv2

# %%
##Getting size of images
list_of_heights = []
list_of_widths = []
for i in os.listdir(dir_path):
    for image in os.listdir(os.path.join(dir_path,i)):
        img = cv2.imread(os.path.join(os.path.join(dir_path,i),image), cv2.IMREAD_UNCHANGED)
        # get dimensions of image
        shape = img.shape
        list_of_heights.append(shape[0])
        list_of_widths.append(shape[1])

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))

  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# name 'take_photo' is not defined

# %%
##plotting
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(list_of_heights,bins=20)
plt.xlim(0,900)
plt.title('heights')
# Out:
# Text(0.5, 1.0, 'heights')

# %%
plt.hist(list_of_widths,bins=20)
plt.title('widths')
plt.xlim(0,900)
# Out:
# (0.0, 900.0)

# %%
np.median(list_of_heights)
# Out:
# 122.0

# %%
np.mean(list_of_heights)
# Out:
# 198.1923467169155

# %%
np.median(list_of_widths)
# Out:
# 231.0

# %%
np.mean(list_of_widths)
# Out:
# 234.86911146542977

# %%
###Image data Generator class
ImageFlow = tf.keras.preprocessing.image.ImageDataGenerator()
##We are fitting the data to Image data generator.
ImageGenerator = ImageFlow.flow_from_directory(dir_path,target_size=(156,256),seed=10,batch_size=32)
# Out:
# Found 6899 images belonging to 8 classes.

# %%
##Checking time taken to load images.
import time
start = time.time()
total_batches = 0

batches = 0
per_batch = 32
for x_batch, y_batch in ImageGenerator:
    batches += 1
    if batches >= 6899/per_batch:
        total_batches = total_batches + batches
        break
end = time.time()
duration = end-start
print("{} batches: {} s".format(total_batches, duration))
print("{:0.5f} Images/s".format(per_batch*total_batches/duration))
# Out:
# 216 batches: 45.370954513549805 s
# 152.34416 Images/s

# %%
6899/32
# Out:
# 215.59375

# %%
#importing tensorflow
from tensorflow.keras.layers import Dense,Input,Conv2D,MaxPool2D,Activation,Dropout,Flatten
from tensorflow.keras.models import Model
import random as rn

# %%
import os
os.environ['PYTHONHASHSEED'] = '0'

##https://keras.io/getting-started/faq/#how-can-i-obtain-reproducible-results-using-keras-during-development
## Have to clear the session. If you are not clearing, Graph will create again and again and graph size will increses.
## Varibles will also set to some value from before session
tf.keras.backend.clear_session()

## Set the random seed values to regenerate the model.
np.random.seed(0)
rn.seed(0)

#Input layer
input_layer = Input(shape=(156,256,3),name='Input_Layer')

#Conv Layer
Conv1 = Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),padding='valid',data_format='channels_last',
              activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed=0),name='Conv1')(input_layer)
#MaxPool Layer
Pool1 = MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid',data_format='channels_last',name='Pool1')(Conv1)


Conv2 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),padding='valid',data_format='channels_last',
              activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed=3),name='Conv2')(Pool1)
Conv3 = Conv2D(filters=64,kernel_size=(3,3),strides=(2,2),padding='valid',data_format='channels_last',
              activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed=5),name='Conv3')(Conv2)
#MaxPool Layer
Pool2 = MaxPool2D(pool_size=(2,2),strides=(1,1),padding='valid',data_format='channels_last',name='Pool2')(Conv3)


Conv4 = Conv2D(filters=128,kernel_size=(3,3),strides=(2,2),padding='valid',data_format='channels_last',
              activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed=9),name='Conv4')(Pool2)
#MaxPool Layer
Pool3 = MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid',data_format='channels_last',name='Pool3')(Conv4)



#Flatten
flatten = Flatten(data_format='channels_last',name='Flatten')(Pool3)

#FC layer
FC1 = Dense(units=30,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=32),name='FC1')(flatten)

#FC layer
FC2 = Dense(units=15,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=33),name='FC2')(FC1)

#output layer
Out = Dense(units=8,activation='softmax',kernel_initializer=tf.keras.initializers.glorot_normal(seed=3),name='Output')(FC2)

#Creating a model
model = Model(inputs=input_layer,outputs=Out)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (InputLayer)    [(None, 156, 256, 3)]     0
#
#  Conv1 (Conv2D)              (None, 154, 254, 32)      896
#
#  Pool1 (MaxPooling2D)        (None, 77, 127, 32)       0
#
#  Conv2 (Conv2D)              (None, 75, 125, 64)       18496
#
#  Conv3 (Conv2D)              (None, 37, 62, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 36, 61, 64)        0
#
#  Conv4 (Conv2D)              (None, 17, 30, 128)       73856
#
#  Pool3 (MaxPooling2D)        (None, 8, 15, 128)        0
#
#  Flatten (Flatten)           (None, 15360)             0
#
#  FC1 (Dense)                 (None, 30)                460830
#
#  FC2 (Dense)                 (None, 15)                465
#
#  Output (Dense)              (None, 8)                 128
#
# =================================================================
# Total params: 591599 (2.26 MB)
# Trainable params: 591599 (2.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#compiling
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.01),loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
##fitting generator
model.fit_generator(ImageGenerator,steps_per_epoch=216,epochs=3)
# Out:
# <ipython-input-80-264c0fcc37e1>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(ImageGenerator,steps_per_epoch=216,epochs=3)
# Epoch 1/3
# 216/216 [==============================] - 616s 3s/step - loss: 14.0097 - accuracy: 0.1338
# Epoch 2/3
# 216/216 [==============================] - 585s 3s/step - loss: 2.0741 - accuracy: 0.1449
# Epoch 3/3
# 216/216 [==============================] - 579s 3s/step - loss: 2.0727 - accuracy: 0.1389

# %% [markdown]
# <pre>
# <b>Data Pipelines with TensorFlow</b>
# </pre>

# %%
#importing pathlib
#please check https://docs.python.org/3/library/pathlib.html  to know about pathlib
import pathlib
data_root = pathlib.Path(dir_path)
print(data_root)
# Out:
# /gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images

# %%
##getting all the directories
list(data_root.iterdir())
# Out:
# [PosixPath('/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/airplane'),
#  PosixPath('/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/car'),
#  PosixPath('/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/cat'),
#  PosixPath('/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/dog'),
#  PosixPath('/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/flower'),
#  PosixPath('/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/fruit'),
#  PosixPath('/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/motorbike'),
#  PosixPath('/gdrive/MyDrive/Named_Assignments/20. CV_TransferLearning/natural_images/person')]

# %%
##Getting all image paths
import random
all_image_paths = list(data_root.glob('*/*'))
all_image_paths = [str(path) for path in all_image_paths]
# ##shuffling the images
# random.shuffle(all_image_paths)

image_count = len(all_image_paths)
image_count
# Out:
# 6899

# %%
#List the available labels
label_names = sorted(item.name for item in data_root.glob('*/') if item.is_dir())
label_names
# Out:
# ['airplane', 'car', 'cat', 'dog', 'flower', 'fruit', 'motorbike', 'person']

# %%
#Assign an index to each label
label_to_index = dict((name, index) for index,name in enumerate(label_names))
label_to_index
# Out:
# {'airplane': 0,
#  'car': 1,
#  'cat': 2,
#  'dog': 3,
#  'flower': 4,
#  'fruit': 5,
#  'motorbike': 6,
#  'person': 7}

# %%
#Create a list of every file, and its label index
all_image_labels = [label_to_index[pathlib.Path(path).parent.name]
                    for path in all_image_paths]

# %%
def tfdata_generator(images, labels, is_training, batch_size=32):
    '''Construct a data generator using tf.Dataset'''

    def parse_function(filename, label):
        #reading path
        image_string = tf.io.read_file(filename)
        #decoding image
        image = tf.image.decode_jpeg(image_string, channels=3)

        # This will convert to float values in [0, 1]
        image = tf.image.convert_image_dtype(image, tf.float32)
        #resize the image
        image = tf.image.resize(image, [156, 256])
        #one hot coding for label
        y = tf.one_hot(tf.cast(label, tf.uint8), 8)
        return image, y

    ##creating a dataset from tensorslices
    dataset = tf.data.Dataset.from_tensor_slices((images, labels))

    if is_training:
        dataset = dataset.shuffle(5000)  # depends on sample size

    # Transform and batch data at the same time
    dataset = dataset.apply(tf.data.experimental.map_and_batch( parse_function, batch_size,num_parallel_batches=4,  # cpu cores
        drop_remainder=True if is_training else False))

    #repeat the dataset indefinitely
    dataset = dataset.repeat()


    #prefetch the data into CPU/GPU
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)

    return dataset

# %% [markdown]
# Please go through this <a href="https://stackoverflow.com/questions/53514495/what-does-batch-repeat-and-shuffle-do-with-tensorflow-dataset">link</a> to see how shuffle,repeat, batch going to work with example.

# %%
#creating a generator
tf_image_generator = tfdata_generator(all_image_paths, all_image_labels, is_training=True, batch_size=32)
# Out:
# WARNING:tensorflow:From <ipython-input-89-6ae42084cbe5>:25: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.

# %%
tf_image_generator
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(32, 156, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(32, 8), dtype=tf.float32, name=None))>

# %%
steps_per_epoch=np.ceil(len(all_image_paths)/32)
steps_per_epoch
# Out:
# 216.0

# %%
##Time taken to load the images
import time
t = 0
start = time.time()
for x, y in tf_image_generator.take(216):
    pass
end = time.time()
duration = end-start
print("{} batches: {} s".format(216, duration))
print("{:0.5f} Images/s".format(32*216/duration))
# Out:
# 216 batches: 37.023991107940674 s
# 186.68976 Images/s

# %%
import os
os.environ['PYTHONHASHSEED'] = '0'

##https://keras.io/getting-started/faq/#how-can-i-obtain-reproducible-results-using-keras-during-development
## Have to clear the session. If you are not clearing, Graph will create again and again and graph size will increses.
## Varibles will also set to some value from before session
tf.keras.backend.clear_session()

## Set the random seed values to regenerate the model.
np.random.seed(0)
rn.seed(0)

#Input layer
input_layer = Input(shape=(156,256,3),name='Input_Layer')

#Conv Layer
Conv1 = Conv2D(filters=32,kernel_size=(3,3),strides=(1,1),padding='valid',data_format='channels_last',
              activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed=0),name='Conv1')(input_layer)
#MaxPool Layer
Pool1 = MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid',data_format='channels_last',name='Pool1')(Conv1)


Conv2 = Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),padding='valid',data_format='channels_last',
              activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed=3),name='Conv2')(Pool1)
Conv3 = Conv2D(filters=64,kernel_size=(3,3),strides=(2,2),padding='valid',data_format='channels_last',
              activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed=5),name='Conv3')(Conv2)
#MaxPool Layer
Pool2 = MaxPool2D(pool_size=(2,2),strides=(1,1),padding='valid',data_format='channels_last',name='Pool2')(Conv3)


Conv4 = Conv2D(filters=128,kernel_size=(3,3),strides=(2,2),padding='valid',data_format='channels_last',
              activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed=9),name='Conv4')(Pool2)
#MaxPool Layer
Pool3 = MaxPool2D(pool_size=(2,2),strides=(2,2),padding='valid',data_format='channels_last',name='Pool3')(Conv4)



#Flatten
flatten = Flatten(data_format='channels_last',name='Flatten')(Pool3)

#FC layer
FC1 = Dense(units=30,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=32),name='FC1')(flatten)

#FC layer
FC2 = Dense(units=15,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=33),name='FC2')(FC1)

#output layer
Out = Dense(units=8,activation='softmax',kernel_initializer=tf.keras.initializers.glorot_normal(seed=3),name='Output')(FC2)

#Creating a model
model = Model(inputs=input_layer,outputs=Out)

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.01),loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
tf_image_generator = tfdata_generator(all_image_paths, all_image_labels, is_training=True, batch_size=32)

# %%
model.fit_generator(tf_image_generator,steps_per_epoch=216,epochs=3)

# %% [markdown]
# <pre>
# 1. The order is important.
#
#   - A <b>shuffle</b> after a <b>repeat</b> would shuffle items across epoch boundaries
#   (some items will be seen twice before others are seen at all).
#   - A <b>shuffle</b> after a <b>batch</b> would shuffle the order of the batches,
#   but not shuffle the items across batches.
#
# 2. We use a <b>buffer_size</b> the same size as the dataset for a full shuffle.
# Up to the dataset size, large values provide better randomization, but use more memory.
#
# 3. The shuffle buffer is filled before any elements are pulled from it.
# So a large <b>buffer_size</b> may cause a delay when your Dataset is starting.
#
# </pre>

# %% [markdown]
# <pre>
# <b> using Cache</b>
# </pre>

# %%
def tfdata_generator(images, labels, is_training, batch_size=32):
    '''Construct a data generator using tf.Dataset'''

    def parse_function(filename, label):
        #reading path
        image_string = tf.io.read_file(filename)
        #decoding image
        image = tf.image.decode_jpeg(image_string, channels=3)

        # This will convert to float values in [0, 1]
        image = tf.image.convert_image_dtype(image, tf.float32)

        image = tf.image.resize(image, [156, 256])

        y = tf.one_hot(tf.cast(label, tf.uint8), 8)
        return image, y

    dataset = tf.data.Dataset.from_tensor_slices((images, labels))

    # Transform and batch data at the same time
    dataset = dataset.map(parse_function,num_parallel_calls=4)

    dataset = dataset.cache('./tf-data')

    dataset = dataset.apply(tf.data.experimental.shuffle_and_repeat(buffer_size=1000))
    dataset = dataset.batch(32).prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %%
tf.keras.backend.clear_session()

# %%
tf_image_generator = tfdata_generator(all_image_paths, all_image_labels, is_training=True, batch_size=32)
# Out:
# WARNING:tensorflow:From <ipython-input-42-2fe814ed792f>:25: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.

# %% [markdown]
# <pre>
# <b>Image augmentation</b>
# </pre>

# %%
def tfdata_generator(images, labels, is_training, batch_size=32):
    '''Construct a data generator using tf.Dataset'''

    def parse_function(filename,labels):
        #reading path
        image_string = tf.io.read_file(filename)
        #decoding image
        image = tf.image.decode_jpeg(image_string, channels=3)

        # This will convert to float values in [0, 1]
        image = tf.image.convert_image_dtype(image, tf.float32)

        image = tf.image.resize(image, [156, 256])

        y = tf.one_hot(tf.cast(labels, tf.uint8), 8)
        return image,y

    def flip(image,labels):

        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_flip_up_down(image)

        return image,labels

    def rotate(image,labels):

        return tf.image.rot90(image, tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32)),labels

    def color(image,labels):
        image = tf.image.random_hue(image, 0.08)
        image = tf.image.random_saturation(image, 0.6, 1.6)
        image = tf.image.random_brightness(image, 0.05)
        image = tf.image.random_contrast(image, 0.7, 1.3)
        return image,labels

    dataset = tf.data.Dataset.from_tensor_slices((images,labels))

    if is_training:
        dataset = dataset.shuffle(5000)  # depends on sample size

    # Transform and batch data at the same time
    dataset = dataset.map(parse_function, num_parallel_calls=4)

    augmentations = [flip,rotate,color]

    if is_training:
      for f in augmentations:
        if np.random.uniform(0,1)>0.6:
            dataset = dataset.map(f,num_parallel_calls=4)

    dataset = dataset.repeat()

    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# <pre>
# Check <a href='https://androidkt.com/tensorflow-image-augmentation-using-tf-image/'>this</a> link for Image Augmentation tech in Tensorflow.

# %%
tf.keras.backend.clear_session()
tf_image_generator = tfdata_generator(all_image_paths, all_image_labels, is_training=True, batch_size=1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for x, y in tf_image_generator:
    print(x.shape)
    plt.imshow(x)
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (156, 256, 3)
